# %%
derivative((-80 + 90*x^0.5-100*x^0.25)/x)
# Out:
# 10*(4.50000000000000/sqrt(x) - 2.50000000000000/x^0.750000000000000)/x - 10*(9*sqrt(x) - 10*x^0.250000000000000 - 8)/x^2

# %%
def f(x): 
    return 10*(4.50000000000000/sqrt(x) - 2.50000000000000/x^0.750000000000000)/x - 10*(9*sqrt(x) - 10*x^0.250000000000000 - 8)/x^2

# %%
f(300)
# Out:
# -0.00500000000000000*sqrt(3) + 0.00435704843079540

# %%
show(plot(70 * x^0.5 - 950 == 0, x, xmin=0, xmax=200, ymin= -1000, ymax = 1000))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
g = Graphics()
g += plot(950 + 15*x^0.5, (x,0,200), color='green')
g += plot(85 * x^0.5, (x,0,200), color='red')
g += plot(70 * x^0.5 - 950, (x,0,200), color='blue')
g.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
eq = 70 * x^0.5 - 950 == 0

# %%
eq.find_root(0, 200)
# Out:
# 184.18367346938783

# %%
derivative(70 * x^0.5 - 950)
# Out:
# 35.0000000000000/sqrt(x)

# %%
eq2 = 35/sqrt(x)

# %%
def g(x): 
    return 35/sqrt(x)

# %%
g(184.184)
# Out:
# 2.57894508237656

# %%
derivative((70 * sqrt(x) - 950)/x)
# Out:
# -10*(7*sqrt(x) - 95)/x^2 + 35/x^(3/2)

# %%
show(plot(-10*(7*sqrt(x) - 95)/x^2 + 35/x^(3/2), x, xmin=0, xmax=10), ymin=0, ymax=500)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(plot((-35*sqrt(x) + 950)/x^2, x, xmin=0, xmax=10), ymin=0, ymax=500)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def h(x):
    return -10*(7*sqrt(x) - 95)/x^2 + 35/x^(3/2)

# %%
h(400)
# Out:
# 1/640

# %%
def i(x):
    return (-35*sqrt(x) + 950)/x^2

# %%
i(400)
# Out:
# 1/640

# %%
i(184.184)
# Out:
# 0.0140019790551385

# %%
def j(x):
    return (0.3*x)/(0.04 + x^2)

# %%
show(plot((0.3*x/(0.04 + x^2)), x, xmin=-50, xmax=50, ymin= -1, ymax = 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
derivative(0.3*x/(0.04 + x^2))
# Out:
# -0.600000000000000*x^2/(x^2 + 0.0400000000000000)^2 + 0.300000000000000/(x^2 + 0.0400000000000000)

# %%
eq3 = -0.600000000000000*x^2/(x^2 + 0.0400000000000000)^2 + 0.300000000000000/(x^2 + 0.0400000000000000) == 0

# %%
eq3.find_root(-1, 0)
# Out:
# -0.20000000000000004

# %%
eq3.find_root(0, 1)
# Out:
# 0.20000000000000004

# %%
show(plot(-0.600000000000000*x^2/(x^2 + 0.0400000000000000)^2 + 0.300000000000000/(x^2 + 0.0400000000000000), x, xmin=-10, xmax=10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(plot((-0.3 * x^2 + 0.012)/(0.04 + x^2)^2, x, xmin=-10, xmax=10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq4 = (-0.3 * x^2 + 0.012)/(0.04 + x^2)^2 == 0

# %%
eq4.find_root(-1, 0)
# Out:
# -0.2

# %%
eq4.find_root(0, 1)
# Out:
# 0.2

# %%
j(-0.2)
# Out:
# -0.750000000000000

# %%
j(0.2)
# Out:
# 0.750000000000000

# %%
derivative((8*x^3 - 1)/(2*x-1))
# Out:
# 24*x^2/(2*x - 1) - 2*(8*x^3 - 1)/(2*x - 1)^2

# %%
derivative(((x-1)*(x^2+x+1))/(x^4-3*x^3-5))
# Out:
# -(4*x^3 - 9*x^2)*(x^2 + x + 1)*(x - 1)/(x^4 - 3*x^3 - 5)^2 + (2*x + 1)*(x - 1)/(x^4 - 3*x^3 - 5) + (x^2 + x + 1)/(x^4 - 3*x^3 - 5)
